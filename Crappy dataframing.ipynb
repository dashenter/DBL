# %%
import pandas as pd
import json
import os
import sqlite3

# %%
l = []

for root, dirs, files in os.walk(".", topdown=False):
    for name in files:
        if name.endswith('.json'):
            l.append(str(os.path.join(name)))

# %%
df = pd.read_json(l[1], lines=True)
# drop columns
columns_to_drop = ['id_str', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'quoted_status_id_str',
                           'favorited', 'retweeted', 'filter_level', 'timestamp_ms', 'retweeted_status', 'delete']
df.drop(columns_to_drop, axis=1, inplace=True)
# print the modified dataframe

list_of_user_values = df['user'].tolist()
list_of_user_names = [n for n in list_of_user_values[0]]
df_user_separate_1 = pd.DataFrame([list_of_user_values[0]])
df_user_separate_1
# Out:
#           id     id_str   name screen_name location   url description  \
# 0  197146011  197146011  DaveM     Waddy6X     None  None        None
#
#   translator_type  protected  verified  ...  profile_sidebar_fill_color  \
# 0            none      False     False  ...                      DDEEF6
#
#    profile_text_color  profile_use_background_image  \
# 0              333333                          True
#
#                                    profile_image_url  \
# 0  http://pbs.twimg.com/profile_images/3788000006...
#
#                              profile_image_url_https default_profile  \
# 0  https://pbs.twimg.com/profile_images/378800000...            True
#
#   default_profile_image following  follow_request_sent notifications
# 0                 False      None                 None          None
#
# [1 rows x 38 columns]

# %%
df = pd.read_json(l[0], lines=True)
# drop columns
columns_to_drop = ['id_str', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'quoted_status_id_str',
                           'favorited', 'retweeted', 'filter_level', 'timestamp_ms', 'retweeted_status', 'delete']
df.drop(columns_to_drop, axis=1, inplace=True)
# print the modified dataframe

list_of_user_values = df['user'].tolist()
list_of_user_names = [n for n in list_of_user_values[0]]
df_user_separate_2 = pd.DataFrame([list_of_user_values[0]])
df_user_separate_2
# Out:
#           id     id_str        name screen_name       location  \
# 0  393374091  393374091  EP Turismo   EPturismo  Madrid, Spain
#
#                                   url  \
# 0  http://www.europapress.es/turismo/
#
#                                          description translator_type  \
# 0  Todo sobre política turística, hoteles, tourop...            none
#
#    protected  verified  ...  profile_text_color  profile_use_background_image  \
# 0      False      True  ...              333333                          True
#
#                                    profile_image_url  \
# 0  http://pbs.twimg.com/profile_images/8771160971...
#
#                              profile_image_url_https  \
# 0  https://pbs.twimg.com/profile_images/877116097...
#
#                                   profile_banner_url default_profile  \
# 0  https://pbs.twimg.com/profile_banners/39337409...           False
#
#   default_profile_image following  follow_request_sent notifications
# 0                 False      None                 None          None
#
# [1 rows x 39 columns]

# %%
table_name = 'Air_line_2'

conn = sqlite3.connect('pythonsqlit3.db')
df.columns = df.columns.str.strip()
df_user_separate_2.to_sql(table_name,conn,if_exists='replace',index=False)
conn.commit()
conn.close()
